# %%
from compliance_checker.runner import ComplianceChecker, CheckSuite
ds_loc = '/home/simonaoliver/data/tiles/LS5_TM_NBAR/LS5_TM_NBAR_3577_-5_-22_20110124011443302075.nc'
#ds_loc='/home/simonaoliver/data/tiles/LS5_TM_LEDAPS/LS5_TM_LEDAPS_3577_7_-41_20111017001548000000.nc'
#ds_loc='/media/simonaoliver/datacube/tiles/S2A_MSI_L1C/S2A_MSI_L1C_10_3577_14_-41_20151205001643498000.nc'
cs = CheckSuite()
ds = cs.load_dataset(ds_loc)
cs.load_all_available_checkers()
score_groups = cs.run(ds, 'ioos')

return_value, errors = ComplianceChecker.run_checker(ds_loc, ['cf','acdd'], 1, 'normal', '-','text')
# Out:
# --------------------------------------------------------------------------------
#                      The dataset scored 51 out of 93 points
#                              during the acdd check
# --------------------------------------------------------------------------------
#                            Verbose Scoring Breakdown:
#
#                                  High Priority
# --------------------------------------------------------------------------------
#     Name                            :Priority: Score
# Conventions                             :3:     2/2
# acknowledgment/acknowledgement          :3:     1/1
# keywords                                :3:     1/1
# summary                                 :3:     1/1
# title                                   :3:     1/1
# varattr                                 :3:    27/52
#     01                                  :3:       1/3
#         var_std_name                    :3:         0/2
# ...
