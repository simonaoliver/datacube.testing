# %%
# %matplotlib inline
import datacube
dc = datacube.Datacube(app='dc-example')
import folium
from IPython.display import display
import geopandas
from shapely.geometry import mapping
from shapely.geometry import MultiPolygon
import rasterio
import shapely.geometry
import shapely.ops
from functools import partial
import pyproj
from datacube.model import CRS

from datacube.storage import masking
import pandas

# %%
def datasets_union(dss):
    return shapely.ops.unary_union([shapely.geometry.Polygon(ds.extent.to_crs(CRS('EPSG:4326')).points) for ds in dss])

# %%
def plot_folium(shapes):
    style_function = lambda x: {'fillColor': '#000000' if x['type'] == 'Polygon' else '#00ff00'}
    mapa = folium.Map(location=[-30,150], zoom_start=4)
    poly = folium.features.GeoJson(mapping(shapes), style_function=style_function)
    mapa.add_children(poly)
    display(mapa)

# %%
dc.list_products()
# Out:
#                             name  \
# id
# 24            h8_ahi_brf_granule
# 25            h8_ahi_obs_granule
# 26          h8_ahi_solar_granule
# 6               ls5_ledaps_scene
# 2               ls5_level1_scene
# 3                 ls5_nbar_scene
# 4                ls5_nbart_scene
# 5                   ls5_pq_scene
# 1   ls5_satellite_telemetry_data
# 12              ls7_ledaps_scene
# 8               ls7_level1_scene
# 9                 ls7_nbar_scene
# 10               ls7_nbart_scene
# 11                  ls7_pq_scene
# 7   ls7_satellite_telemetry_data
# 18              ls8_ledaps_scene
# 14              ls8_level1_scene
# 15                ls8_nbar_scene
# 16               ls8_nbart_scene
# 17                  ls8_pq_scene
# 13  ls8_satellite_telemetry_data
# 20            modis_mcd43a1_tile
# 21            modis_mcd43a2_tile
# 22            modis_mcd43a3_tile
# 23            modis_mcd43a4_tile
# 28         s2a_level1c_albers_10
# 27         s2a_level1c_albers_60
# 19           s2a_level1c_granule
#
#                                           description     platform  \
# id
# 24                 H8 BRF, 2km, 1km and 500m granules   HIMAWARI_8
# 25                               H8 OBS, 2km granules   HIMAWARI_8
# 26      H8 SOLAR GEOMETRY, 2km, 1km and 500m granules   HIMAWARI_8
# 6                           Landsat 5 LEDAPS 25 metre    LANDSAT_5
# 2       Landsat 5 Level 1 At-sensor Radiance 25 metre    LANDSAT_5
# 3                             Landsat 5 NBAR 25 metre    LANDSAT_5
# 4                            Landsat 5 NBART 25 metre    LANDSAT_5
# 5                               Landsat 5 PQ 25 metre    LANDSAT_5
# 1                  Landsat 5 Satellite Telemetry Data    LANDSAT_5
# 12                          Landsat 7 LEDAPS 25 metre    LANDSAT_7
# 8       Landsat 7 Level 1 At-sensor Radiance 25 metre    LANDSAT_7
# 9                             Landsat 7 NBAR 25 metre    LANDSAT_7
# 10                           Landsat 7 NBART 25 metre    LANDSAT_7
# 11                              Landsat 7 PQ 25 metre    LANDSAT_7
# 7                  Landsat 7 Satellite Telemetry Data    LANDSAT_7
# 18                          Landsat 8 LEDAPS 25 metre    LANDSAT_8
# 14      Landsat 8 Level 1 At-sensor Radiance 25 metre    LANDSAT_8
# 15                            Landsat 8 NBAR 25 metre    LANDSAT_8
# 16                           Landsat 8 NBART 25 metre    LANDSAT_8
# 17                              Landsat 8 PQ 25 metre    LANDSAT_8
# 13                 Landsat 8 Satellite Telemetry Data    LANDSAT_8
# 20                            MODIS 500 metre MCD43A1   AQUA_TERRA
# 21                            MODIS 500 metre MCD43A2   AQUA_TERRA
# 22                            MODIS 500 metre MCD43A3   AQUA_TERRA
# 23                            MODIS 500 metre MCD43A4   AQUA_TERRA
# 28  Sentinel-2A MSI L1C 10 metre, 100km tile, Aust...  SENTINEL_2A
# 27  Sentinel-2A MSI L1C 60 metre, 100km tile, Aust...  SENTINEL_2A
# 19               Sentinel-2 Level 1 - Ortho Rectified  SENTINEL_2A
#
#                 product_type instrument             format        crs  \
# id
# 24                       BRF        AHI             NETCDF        NaN
# 25                       OBS        AHI             NETCDF        NaN
# 26                GEOM_SOLAR        AHI             NETCDF        NaN
# 6                     ledaps         TM            GeoTiff        NaN
# 2                     level1         TM            GeoTiff        NaN
# 3                       nbar         TM            GeoTiff        NaN
# 4                      nbart         TM            GeoTiff        NaN
# 5                        pqa         TM            GeoTiff        NaN
# 1   satellite_telemetry_data         TM                NaN        NaN
# 12                    ledaps        ETM            GeoTiff        NaN
# 8                     level1        ETM            GeoTiff        NaN
# 9                       nbar        ETM            GeoTiff        NaN
# 10                     nbart        ETM            GeoTiff        NaN
# 11                       pqa        ETM            GeoTiff        NaN
# 7   satellite_telemetry_data        ETM                NaN        NaN
# 18                    LEDAPS   OLI_TIRS            GeoTiff        NaN
# 14                    level1        OLI            GeoTiff        NaN
# 15                      nbar        OLI            GeoTiff        NaN
# 16                     nbart        OLI            GeoTiff        NaN
# 17                       pqa        ETM            GeoTiff        NaN
# 13  satellite_telemetry_data        OLI                NaN        NaN
# 20                   MCD43A1      MODIS  HDF4_EOS:EOS_GRID        NaN
# 21                   MCD43A2      MODIS  HDF4_EOS:EOS_GRID        NaN
# 22                   MCD43A3      MODIS  HDF4_EOS:EOS_GRID        NaN
# 23                   MCD43A4      MODIS  HDF4_EOS:EOS_GRID        NaN
# 28                   S2MSI1C        MSI             NetCDF  EPSG:3577
# 27                   S2MSI1C        MSI             NetCDF  EPSG:3577
# 19                   S2MSI1C        MSI           JPEG2000        NaN
#
#    resolution             tile_size spatial_dimensions
# id
# 24        NaN                   NaN                NaN
# 25        NaN                   NaN                NaN
# 26        NaN                   NaN                NaN
# 6         NaN                   NaN                NaN
# 2         NaN                   NaN                NaN
# 3         NaN                   NaN                NaN
# 4         NaN                   NaN                NaN
# 5         NaN                   NaN                NaN
# 1         NaN                   NaN                NaN
# 12        NaN                   NaN                NaN
# 8         NaN                   NaN                NaN
# 9         NaN                   NaN                NaN
# 10        NaN                   NaN                NaN
# 11        NaN                   NaN                NaN
# 7         NaN                   NaN                NaN
# 18        NaN                   NaN                NaN
# 14        NaN                   NaN                NaN
# 15        NaN                   NaN                NaN
# 16        NaN                   NaN                NaN
# 17        NaN                   NaN                NaN
# 13        NaN                   NaN                NaN
# 20        NaN                   NaN                NaN
# 21        NaN                   NaN                NaN
# 22        NaN                   NaN                NaN
# 23        NaN                   NaN                NaN
# 28  [-10, 10]  [100000.0, 100000.0]             (y, x)
# 27  [-60, 60]  [100000.0, 100000.0]             (y, x)
# 19        NaN                   NaN                NaN

# %%
plot_folium(datasets_union(dc.index.datasets.search_eager(product='s2a_level1c_albers_60')))
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;"></iframe></div></div>

# %%
s2a_l1c = dc.load(product='s2a_level1c_albers_60',x=(147.36, 147.41), y=(-35.1, -35.15),)

# %%
s2a_l1c.data_vars
# Out:
# Data variables:
#     aerosol       (time, y, x) int16 1616 1584 1585 1525 1551 1570 1556 1555 ...
#     water_vapour  (time, y, x) int16 1414 1255 1239 1138 1088 1126 1075 1087 ...
#     cirrus        (time, y, x) int16 191 202 184 182 189 172 159 156 155 164 ...

# %%
s2a_l1c.blue.plot(robust='True')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-21-21ffdc2397cc> in <module>()
# ----> 1 s2a_l1c.blue.plot(robust='True')
#
# /home/simonaoliver/venvs/agdc-v2/local/lib/python2.7/site-packages/xarray/core/common.pyc in __getattr__(self, name)
#     135                     return source[name]
#     136         raise AttributeError("%r object has no attribute %r" %
# --> 137                              (type(self).__name__, name))
#     138
#     139     def __setattr__(self, name, value):
#
# AttributeError: 'Dataset' object has no attribute 'blue'
